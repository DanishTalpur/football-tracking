# %%
from ultralytics import YOLO
model= YOLO("model\\best.pt")

# %%
result= model("D:\Programing\python\ML\Football\\08fd33_4.mp4", save=True)
print(result[0])
print("------------------------------")
for box in result[0].boxes:
    print(box)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) D:\Programing\python\ML\Football\08fd33_4.mp4: 384x640 26 players, 5 referees, 2125.5ms
# video 1/1 (frame 2/750) D:\Programing\python\ML\Football\08fd33_4.mp4: 384x640 26 players, 5 referees, 1643.7ms
# video 1/1 (frame 3/750) D:\Programing\python\ML\Football\08fd33_4.mp4: 384x640 28 players, 6 referees, 1631.7ms
# ...
